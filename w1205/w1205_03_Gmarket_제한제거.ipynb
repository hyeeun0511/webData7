# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import time
import os
import random
from selenium.webdriver.chrome.options import Options

# 상단 Chrome이 자동화된 테스트 소프트웨어에 의해 제어되고 있습니다 제거
options = Options()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument("--disable-blink-features=AutomationControlled")

# %%
for i in range(1,6):  # gmarket - 1~5페이지
    url = "https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p={i}"
    print(url)
# Out:
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p={i}
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p={i}
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p={i}
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p={i}
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p={i}

# %%
# selenium 실행
# 1페이지
url = "https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.5219486adfeIbX&keyword=tv&p=1"
browser = webdriver.Chrome()  # 창열기
browser.maximize_window()
# G마켓 tv 페이지 열기
browser.get(url)

# %%
soup = BeautifulSoup(browser.page_source,"lxml")
# 화면 전체
dss = soup.find("div",{"id":"region__content-body"})  
# 순위 전체 중 절반
ds = dss.find_all("div",{"class":"section__module-wrap"})   
# 1번째  ds[1]
a = ds[1].find("div",{"class":"box__component"})

# %%
# 1번째 전체정보
f = a.find_all("div",{"class":"box__component box__component-itemcard box__component-itemcard--general module-exp-spm-c"})
len(f)  #####

# fs = f[1].find_all("div",{"class":"box__item-container"})

# 1 - 제목
# title = f.find("span",{"class":"text__item-title"})






# len(ds)
# h = divs.find("h3")  # 전체
# #첫번째
# print(h)
# Out:
# 0

# %%
# 첫번째 페이지
headers ={"User-Again":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"}

# 첫번째의 전체내용 들고오기
tds = [1].find_all("")
# 제목
